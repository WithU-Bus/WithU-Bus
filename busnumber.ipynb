# %% [markdown]
# ## 버스 노선 수 전처리

# %%
# 필요한 lib 설정
import pandas as pd
import numpy as np

# %%
# 노선 excel 파일 열기
bn = pd.read_excel('res\운행계통.xlsx')
bn
# Out:
#         연번  노선번호  업체   기점    경유지         종점  평일_운행대수  토요일_운행대수  공휴일_운행대수  \
# 0      1.0     2  동원  다대포     하단        부산역     18.0      18.0      17.0
# 1      2.0     3  동진  다대포     하단     신호주거단지     15.0      12.0      12.0
# 2      3.0   5-1  삼성  회동동     서면    국제여객터미널     16.0      13.0      13.0
# 3      4.0     6  남부  청학동    남포동         괴정     20.0      17.0      15.0
# 4      5.0     7  남부  청학동    남포동  수산가공선진화단지      8.0       7.0       6.0
# ..     ...   ...  ..  ...    ...        ...      ...       ...       ...
# 178  144.0  2000  동남  NaN    NaN        NaN      2.0       2.0       2.0
# 179    NaN  2000  동원  NaN    NaN        NaN      1.0       1.0       1.0
# 180    NaN  2000  동진  NaN    NaN        NaN      1.0       1.0       1.0
# 181    NaN  2000  태영  NaN    NaN        NaN      1.0       1.0       1.0
# 182    NaN  2000   계  하단역  명지,외포      거제 연초      5.0       5.0       5.0
#
#      예비대수  ...  휴식소요시간(분)  평일첨두_배차간격  평일비첨두_배차간격  토요일첨두_배차간격  공휴일비첨두_배차간격  \
# ...

# %%
bn.head(1)
# Out:
#     연번 노선번호  업체   기점 경유지   종점  평일_운행대수  토요일_운행대수  공휴일_운행대수  예비대수  ...  \
# 0  1.0    2  동원  다대포  하단  부산역     18.0      18.0      17.0   1.0  ...
#
#    휴식소요시간(분)  평일첨두_배차간격  평일비첨두_배차간격  토요일첨두_배차간격  공휴일비첨두_배차간격  1대당횟수(평일)  \
# 0       20.0        7.0        11.0        10.0         11.0        5.7
#
#    1일총횟수(평일)  1일총횟수(토요일)  1일총횟수(공휴일)        첫차~막차
# 0      102.0       102.0       100.0  05:00~22:15
#
# [1 rows x 22 columns]

# %%
# 컬럼 명 확인하기
bn.columns
# Out:
# Index(['연번', '노선번호', '업체', '기점', '경유지', '종점', '평일_운행대수', '토요일_운행대수',
#        '공휴일_운행대수', '예비대수', '운행거리(km)', '운행소요시간(분)', '휴식소요시간(분)', '평일첨두_배차간격',
#        '평일비첨두_배차간격', '토요일첨두_배차간격', '공휴일비첨두_배차간격', '1대당횟수(평일)', '1일총횟수(평일)',
#        '1일총횟수(토요일)', '1일총횟수(공휴일)', '첫차~막차'],
#       dtype='object')

# %%
# 필요없는 컬럼 삭제하기
bn.drop(['연번','업체'], axis=1)
# Out:
#      노선번호   기점    경유지         종점  평일_운행대수  토요일_운행대수  공휴일_운행대수  예비대수  운행거리(km)  \
# 0       2  다대포     하단        부산역     18.0      18.0      17.0   1.0      39.8
# 1       3  다대포     하단     신호주거단지     15.0      12.0      12.0   1.0      49.3
# 2     5-1  회동동     서면    국제여객터미널     16.0      13.0      13.0   1.0      56.1
# 3       6  청학동    남포동         괴정     20.0      17.0      15.0   1.0      38.3
# 4       7  청학동    남포동  수산가공선진화단지      8.0       7.0       6.0   1.0      30.7
# ..    ...  ...    ...        ...      ...       ...       ...   ...       ...
# 178  2000  NaN    NaN        NaN      2.0       2.0       2.0   0.0       NaN
# 179  2000  NaN    NaN        NaN      1.0       1.0       1.0   0.0       NaN
# 180  2000  NaN    NaN        NaN      1.0       1.0       1.0   0.0       NaN
# 181  2000  NaN    NaN        NaN      1.0       1.0       1.0   1.0       NaN
# 182  2000  하단역  명지,외포      거제 연초      5.0       5.0       5.0   1.0     110.0
#
# ...

# %%
bn.to_csv('busnumber.csv', encoding='utf-8')
