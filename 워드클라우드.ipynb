# %%
import pandas as pd
from collections import Counter
from konlpy.tag import Okt
import csv

# %% [markdown]
# # 부산_저상버스

# %%
filename = './news_crawing/res/부산_저상버스_요약.csv'
f = open(filename, 'r', encoding='utf-8')
news = f.read()

# %%
# Okt 객체 생성
okt = Okt()
noun = okt.nouns(news)
for i, v in enumerate(noun):
    if len(v) < 2:
        noun.pop(i)
        
count  = Counter(noun)
f.close()

# %%
# 명사 빈도 카운트
noun_list = count.most_common(180)
for v  in noun_list:
    print(v)
# Out:
# ('버스', 457)
# ('장애인', 395)
# ('교통', 232)
# ('휠체어', 211)
# ('부산', 209)
# ('저상버스', 187)
# ('서울', 149)
# ('도입', 124)
# ('운행', 122)
# ('이용', 115)
# ('약자', 113)
# ('동권', 96)
# ('부산시', 93)
# ('지원', 91)
# ('기자', 91)
# ('위해', 89)
# ('사업', 89)
# ('계획', 88)
# ('노선', 87)
# ('전기', 85)
# ('탑승', 84)
# ('고속버스', 80)
# ('후보', 76)
# ('확대', 76)
# ('운영', 76)
# ('시내버스', 75)
# ('지역', 74)
# ('지하철', 73)
# ('올해', 70)
# ('예산', 66)
# ('수소', 64)
# ('정책', 63)
# ('이동', 63)
# ('편의', 63)
# ('설치', 62)
# ('트램', 62)
# ('서비스', 59)
# ('정부', 58)
# ('대중교통', 58)
# ('시설', 57)
# ('택시', 56)
# ('보장', 54)
# ('지자체', 54)
# ('전국', 52)
# ('도시', 51)
# ('사회', 50)
# ('내년', 48)
# ('대한', 48)
# ('개선', 48)
# ('말', 48)
# ('국내', 47)
# ('에디슨', 47)
# ('때문', 45)
# ('지난해', 45)
# ('대해', 44)
# ('안전', 44)
# ('센터', 44)
# ('시간', 43)
# ('수단', 43)
# ('시범', 42)
# ('모터', 41)
# ('문제', 40)
# ('시민', 40)
# ('시작', 40)
# ('지난', 39)
# ('경남', 39)
# ('시장', 39)
# ('남구', 39)
# ('차별', 38)
# ('제공', 38)
# ('관련', 38)
# ('마련', 37)
# ('추진', 37)
# ('구축', 37)
# ...

# %%
# csv 파일로 저장
with open("./res/부산_저상버스.csv","w", newline='') as f:
    csvw = csv.writer(f)
    for v in noun_list:
        csvw.writerow(v)

# %% [markdown]
# # 저상버스 불편

# %%
filename = './news_crawing/res/저상버스_불편_요약.csv'
f = open(filename, 'r', encoding='utf-8')
news = f.read()

# %%
# Okt 객체 생성
okt = Okt()
noun = okt.nouns(news)
for i, v in enumerate(noun):
    if len(v) < 2:
        noun.pop(i)
        
count  = Counter(noun)
f.close()

# %%
# 명사 빈도 카운트
noun_list = count.most_common(180)
for v  in noun_list:
    print(v)
# Out:
# ('장애인', 4074)
# ('버스', 1824)
# ('저상버스', 1330)
# ('교통', 1234)
# ('지하철', 1149)
# ('대표', 1048)
# ('시위', 1032)
# ('휠체어', 966)
# ('동권', 964)
# ('이용', 873)
# ('서울', 733)
# ('약자', 703)
# ('장연', 671)
# ('도입', 635)
# ('운행', 584)
# ('보장', 534)
# ('위해', 530)
# ('차별', 530)
# ('이준석', 523)
# ('시민', 495)
# ('예산', 487)
# ('이동', 487)
# ('시내버스', 476)
# ('노선', 475)
# ('문제', 474)
# ('전국', 470)
# ('설치', 466)
# ('국민', 456)
# ('기자', 454)
# ('철폐', 421)
# ('택시', 415)
# ('연대', 411)
# ('시설', 397)
# ('때문', 394)
# ('편의', 383)
# ('불편', 380)
# ('요구', 377)
# ('단체', 363)
# ('계획', 338)
# ('대해', 338)
# ('의원', 329)
# ('서울시', 327)
# ('권리', 324)
# ('엘리베이터', 321)
# ('지역', 319)
# ('대중교통', 305)
# ('대한', 302)
# ('생각', 300)
# ('후보', 300)
# ('장애', 298)
# ('우리', 296)
# ('것', 293)
# ('말', 288)
# ('호선', 287)
# ('사람', 283)
# ('사회', 279)
# ('출근길', 278)
# ('박경석', 271)
# ('정책', 268)
# ('지원', 266)
# ('개선', 262)
# ('경우', 260)
# ('시간', 259)
# ('정부', 255)
# ('탑승', 254)
# ('운영', 253)
# ('관련', 251)
# ('수단', 250)
# ('지난', 248)
# ...

# %%
# csv 파일로 저장
with open("./res/저상버스_불편.csv","w", newline='') as f:
    csvw = csv.writer(f)
    for v in noun_list:
        csvw.writerow(v)

# %% [markdown]
# #  부산 장애인 이동권

# %%
filename = './news_crawing/res/부산_장애인_이동권_요약.csv'
f = open(filename, 'r', encoding='utf-8')
news = f.read()

# %%
# Okt 객체 생성
okt = Okt()
noun = okt.nouns(news)
for i, v in enumerate(noun):
    if len(v) < 2:
        noun.pop(i)
        
count  = Counter(noun)
f.close()

# %%
# 명사 빈도 카운트
noun_list = count.most_common(180)
for v  in noun_list:
    print(v)
# Out:
# ('장애인', 956)
# ('부산', 345)
# ('후보', 322)
# ('휠체어', 292)
# ('교통', 249)
# ('동권', 249)
# ('서울', 239)
# ('대표', 214)
# ('사회', 190)
# ('위해', 170)
# ('국민', 162)
# ('지원', 151)
# ('윤석열', 146)
# ('이용', 140)
# ('보장', 134)
# ('약자', 133)
# ('기자', 130)
# ('저상버스', 128)
# ('문제', 125)
# ('버스', 124)
# ('운영', 124)
# ('지역', 123)
# ('시민', 120)
# ('지하철', 119)
# ('이준석', 116)
# ('대한', 112)
# ('전국', 109)
# ('사람', 107)
# ('차별', 104)
# ('택시', 103)
# ('부산시', 103)
# ('시설', 101)
# ('장애', 101)
# ('사업', 101)
# ('때문', 100)
# ('정부', 98)
# ('이동', 97)
# ('도입', 91)
# ('탑승', 90)
# ('대해', 88)
# ('민주당', 88)
# ('정책', 87)
# ('도시', 85)
# ('의원', 83)
# ('공약', 83)
# ('대통령', 83)
# ('편의', 82)
# ('설치', 82)
# ('생각', 82)
# ('통해', 81)
# ('센터', 80)
# ('서비스', 79)
# ('지금', 79)
# ('고속버스', 78)
# ('우리', 76)
# ('확대', 74)
# ('것', 73)
# ('교육', 73)
# ('이야기', 72)
# ('지난', 70)
# ('한국', 67)
# ('광주', 66)
# ('수', 66)
# ('대선', 65)
# ('말', 64)
# ('얘기', 64)
# ('활동', 63)
# ('연대', 62)
# ('선거', 62)
# ('애인', 61)
# ('도시철도', 61)
# ('수단', 60)
# ('예산', 60)
# ...

# %%
# csv 파일로 저장
with open("./res/부산_장애인_이동권.csv","w", newline='') as f:
    csvw = csv.writer(f)
    for v in noun_list:
        csvw.writerow(v)

# %% [markdown]
# # 부산 장애인 교통

# %%
filename = './news_crawing/res/부산_장애인_교통_요약.csv'
f = open(filename, 'r', encoding='utf-8')
news = f.read()

# %%
# Okt 객체 생성
okt = Okt()
noun = okt.nouns(news)
for i, v in enumerate(noun):
    if len(v) < 2:
        noun.pop(i)
        
count  = Counter(noun)
f.close()

# %%
# 명사 빈도 카운트
noun_list = count.most_common(180)
for v  in noun_list:
    print(v)
# Out:
# ('부산', 3890)
# ('장애인', 3307)
# ('사업', 2457)
# ('지역', 2269)
# ('서울', 2218)
# ('한국', 2109)
# ('교통', 2029)
# ('지원', 1823)
# ('위해', 1731)
# ('사회', 1666)
# ('기자', 1562)
# ('의원', 1494)
# ('대표', 1419)
# ('시민', 1404)
# ('정부', 1396)
# ('후보', 1346)
# ('운영', 1319)
# ('국민', 1154)
# ('정책', 1152)
# ('이용', 1150)
# ('전국', 1147)
# ('시설', 1126)
# ('부산시', 1058)
# ('서비스', 1056)
# ('추진', 1049)
# ('안전', 1043)
# ('대한', 1030)
# ('문제', 1023)
# ('도시', 1010)
# ('때문', 968)
# ('계획', 968)
# ('제공', 957)
# ('센터', 956)
# ('통해', 936)
# ('공사', 933)
# ('복지', 913)
# ('우리', 896)
# ('위원회', 884)
# ('관리', 859)
# ('지난', 853)
# ('휠체어', 846)
# ('사람', 836)
# ('것', 821)
# ('대상', 817)
# ('지난해', 812)
# ('산업', 806)
# ('버스', 802)
# ('생각', 801)
# ('경우', 790)
# ('관련', 790)
# ('대통령', 785)
# ('지금', 781)
# ('문화', 758)
# ('민주당', 736)
# ('개발', 735)
# ('대해', 733)
# ('오후', 732)
# ('코로나', 730)
# ('설치', 723)
# ('노인', 723)
# ('오전', 720)
# ('주택', 718)
# ('지하철', 714)
# ('예산', 712)
# ('주민', 711)
# ('경제', 699)
# ('진행', 696)
# ('도시철도', 696)
# ...

# %%
# csv 파일로 저장
with open("./res/부산_장애인_교통.csv","w", newline='') as f:
    csvw = csv.writer(f)
    for v in noun_list:
        csvw.writerow(v)

# %% [markdown]
# # 병합

# %%
a = pd.read_csv('res\부산_장애인_이동권.csv', encoding='cp949', header=None)
a.columns = ['단어', '빈도수']
a
# Out:
#       단어  빈도수
# 0    장애인  956
# 1     부산  345
# 2     후보  322
# 3    휠체어  292
# 4     교통  249
# ..   ...  ...
# 175   노력   33
# 176   경기   33
# 177   마련   33
# 178   오늘   33
# 179   실제   33
#
# [180 rows x 2 columns]

# %%
b = pd.read_csv('res\부산_저상버스.csv', encoding='cp949', header=None)
b.columns = ['단어', '빈도수']
b
# Out:
#       단어  빈도수
# 0     버스  457
# 1    장애인  395
# 2     교통  232
# 3    휠체어  211
# 4     부산  209
# ..   ...  ...
# 175   공급   21
# 176   단체   20
# 177   우리   20
# 178   중심   20
# 179   문화   20
#
# [180 rows x 2 columns]

# %%
c = pd.read_csv('res\저상버스_불편.csv', encoding='cp949', header=None)
c.columns = ['단어', '빈도수']
c
# Out:
#        단어   빈도수
# 0     장애인  4074
# 1      버스  1824
# 2    저상버스  1330
# 3      교통  1234
# 4     지하철  1149
# ..    ...   ...
# 175   위원회    99
# 176     고    99
# 177    광주    98
# 178    다시    98
# 179    내년    97
#
# [180 rows x 2 columns]

# %%
d = pd.read_csv('res\부산_장애인_교통.csv', encoding='cp949', header=None)
d.columns = ['단어', '빈도수']
d
# Out:
#       단어   빈도수
# 0     부산  3890
# 1    장애인  3307
# 2     사업  2457
# 3     지역  2269
# 4     서울  2218
# ..   ...   ...
# 175   연합   373
# 176   가족   373
# 177   의료   371
# 178   지방   371
# 179   이후   370
#
# [180 rows x 2 columns]

# %%
total = pd.concat([a, b, c, d])
total
# Out:
#       단어  빈도수
# 0    장애인  956
# 1     부산  345
# 2     후보  322
# 3    휠체어  292
# 4     교통  249
# ..   ...  ...
# 175   연합  373
# 176   가족  373
# 177   의료  371
# 178   지방  371
# 179   이후  370
#
# [720 rows x 2 columns]

# %%
total = total.groupby(['단어'])['빈도수'].sum()
total
# Out:
# 단어
# 가운데     581
# 가장      677
# 가족      373
# 가지      527
# 개       443
#        ...
# 회사       21
# 회의      416
# 회장      622
# 후보     2044
# 휠체어    2315
# Name: 빈도수, Length: 317, dtype: int64

# %%
from wordcloud import WordCloud
import matplotlib.pylab as plt
from PIL import Image
import pandas as pd
import numpy as np

# %%
wc = WordCloud(font_path='malgun', background_color='#f5f5f5', width=1280, height=760)
cloud = wc.generate_from_frequencies(total)

plt.figure(figsize=(30,10))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
img = Image.open('./data/bus.png')
img_array = np.array(img)

wc = WordCloud(font_path='malgun', width=400, height=200, scale=2.0, max_font_size=500, mask=img_array, background_color = 'white')
gen = wc.generate_from_frequencies(total)

plt.figure(figsize=(15,10))
plt.axis(False)
plt.imshow(gen)

# %%
img = Image.open('./data/image.png')
img_array = np.array(img)

wc = WordCloud(font_path='malgun', width=400, height=200, scale=2.0, max_font_size=500, mask=img_array, background_color = 'white', contour_color='blue', contour_width=4)
gen = wc.generate_from_frequencies(total)

plt.figure(figsize=(15,10))
plt.axis(False)
plt.imshow(gen)
