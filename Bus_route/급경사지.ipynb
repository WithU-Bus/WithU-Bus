# %%
import pandas as pd
import json
import folium
import numpy as np

# %% [markdown]
# ### 급경사지 데이터 불러오기(위험등급O)

# %%
gangseo = pd.read_excel('C:/Users/admin/Desktop/WithU-HJ/data/강서구_급경사지.xlsx')
gangseo.head()
# Out:
#    관리구                      위치          X           Y 위험등급
# 0  강서구  부산광역시 강서구 녹산동 산127-1번지  35.110905  128.858528    C
# 1  강서구   부산광역시 강서구 녹산동 산97-5번지  35.111529  128.864550    C
# 2  강서구    부산광역시 강서구 녹산동 2-22번지  35.127722  128.899481    C
# 3  강서구   부산광역시 강서구 녹산동 산47-2번지  35.112630  128.873663    C
# 4  강서구    부산광역시 강서구 녹산동 5-65번지  35.126138  128.898639    C

# %%
sasang = pd.read_excel('C:/Users/admin/Desktop/WithU-HJ/data/사상구_급경사지.xlsx')
sasang.head()
# Out:
#    관리구                                   위치          X           Y 위험등급
# 0  사상구  덕포동 775-1(덕상로 32), 덕상초등학교 주변 괘내교 인근  35.174645  128.990633    C
# 1  사상구                  엄궁동 141-15, ㈜이비알 근처  35.124170  128.965570    B
# 2  사상구                 엄궁동 138-2(엄궁로 70-10)  35.123331  128.974723    C
# 3  사상구              학장동 210-3번지, (동양아파트 일원)  35.143358  128.991617    C
# 4  사상구   주례동 616-4(주례로139번길 8), 주례벽산아파트 경사지  35.145078  129.001272    C

# %%
yeonje = pd.read_excel('C:/Users/admin/Desktop/WithU-HJ/data/연제구_급경사지.xlsx')
yeonje.head()
# Out:
#    관리구                위치          X           Y 위험등급
# 0  연제구  연제구 연산동 산181-4번지  35.159713  129.083019    B
# 1  연제구  연제구 연산동 산134-1번지  35.183389  129.089348    C
# 2  연제구  연제구 연산동 산182-1번지  35.162434  129.080135    B
# 3  연제구   연제구 연산동 산46-5번지  35.175777  129.095004    B
# 4  연제구  연제구 연산동 산123-3번지  35.182914  129.092423    C

# %%
seo = pd.read_excel('C:/Users/admin/Desktop/WithU-HJ/data/서구_급경사지.xlsx')
seo.head()
# Out:
#   관리구         위치          X           Y 위험등급
# 0  서구    암남동 665  35.077501  129.006815    C
# 1  서구   암남동 64-2  35.081051  129.017278    C
# 2  서구  암남동 81-23  35.080032  129.018201    C
# 3  서구  암남동 604-2  35.071357  129.015888    C
# 4  서구  암남동 611-5  35.070487  129.016989    C

# %%
a = pd.concat([sasang, gangseo, yeonje, seo])
a = a.reset_index(drop='true')
a
# Out:
#      관리구                                   위치          X           Y 위험등급
# 0    사상구  덕포동 775-1(덕상로 32), 덕상초등학교 주변 괘내교 인근  35.174645  128.990633    C
# 1    사상구                  엄궁동 141-15, ㈜이비알 근처  35.124170  128.965570    B
# 2    사상구                 엄궁동 138-2(엄궁로 70-10)  35.123331  128.974723    C
# 3    사상구              학장동 210-3번지, (동양아파트 일원)  35.143358  128.991617    C
# 4    사상구   주례동 616-4(주례로139번길 8), 주례벽산아파트 경사지  35.145078  129.001272    C
# ..   ...                                  ...        ...         ...  ...
# 136   서구                           암남동 산193-4  35.055922  129.015409    C
# 137   서구                           암남동 산193-5  35.060878  129.016105    C
# 138   서구                           암남동 645-12  35.074673  129.007394    D
# 139   서구                           암남동 산107-5  35.067240  129.011138    C
# 140   서구                           암남동 633-25  35.070771  129.009322    C
#
# [141 rows x 5 columns]

# %% [markdown]
# ### 급경사지 데이터 불러오기(위험등급X)

# %%
youngdo = pd.read_excel('C:/Users/admin/Desktop/WithU-HJ/data/영도구_급경사지.xlsx')
youngdo.head()
# Out:
#    관리구                      위치          X           Y
# 0  영도구   부산광역시 영도구 영선동4가 산 30   35.074594  129.051187
# 1  영도구    부산광역시 영도구 청학동48-236   35.093335  129.067633
# 2  영도구  부산광역시 영도구 동삼동 산 149-8   35.072009  129.056050
# 3  영도구     부산광역시 영도구 동삼동672-5   35.071852  129.073690
# 4  영도구       부산광역시 영도구 동삼동537   35.071872  129.068025

# %%
gumjung = pd.read_excel('C:/Users/admin/Desktop/WithU-HJ/data/금정구_급경사지.xlsx')
gumjung.head()
# Out:
#    관리구           위치          X           Y
# 0  금정구  구서동 722-1번지  35.251216  129.084369
# 1  금정구    청룡동 산20-1  35.281625  129.087049
# 2  금정구    부곡동 354-4  35.233434  129.096193
# 3  금정구  부곡동 694-2번지  35.224439  129.098942
# 4  금정구    부곡동 965번지  35.230362  129.095562

# %%
b = pd.concat([youngdo, gumjung])
b = b.reset_index(drop='true')
b
# Out:
#     관리구                      위치          X           Y
# 0   영도구   부산광역시 영도구 영선동4가 산 30   35.074594  129.051187
# 1   영도구    부산광역시 영도구 청학동48-236   35.093335  129.067633
# 2   영도구  부산광역시 영도구 동삼동 산 149-8   35.072009  129.056050
# 3   영도구     부산광역시 영도구 동삼동672-5   35.071852  129.073690
# 4   영도구       부산광역시 영도구 동삼동537   35.071872  129.068025
# ..  ...                     ...        ...         ...
# 72  금정구             청룡동 176-1번지  35.277920  129.080970
# 73  금정구             금성동 520-3번지  35.252502  129.057208
# 74  금정구              선동 76-11번지  35.260309  129.118503
# 75  금정구            구서동 266-16번지  35.252358  129.093173
# 76  금정구              회동동 산129번지  35.244234  129.136831
#
# [77 rows x 4 columns]

# %%
b['위험등급'] = np.NaN
b
# Out:
#     관리구                      위치          X           Y  위험등급
# 0   영도구   부산광역시 영도구 영선동4가 산 30   35.074594  129.051187   NaN
# 1   영도구    부산광역시 영도구 청학동48-236   35.093335  129.067633   NaN
# 2   영도구  부산광역시 영도구 동삼동 산 149-8   35.072009  129.056050   NaN
# 3   영도구     부산광역시 영도구 동삼동672-5   35.071852  129.073690   NaN
# 4   영도구       부산광역시 영도구 동삼동537   35.071872  129.068025   NaN
# ..  ...                     ...        ...         ...   ...
# 72  금정구             청룡동 176-1번지  35.277920  129.080970   NaN
# 73  금정구             금성동 520-3번지  35.252502  129.057208   NaN
# 74  금정구              선동 76-11번지  35.260309  129.118503   NaN
# 75  금정구            구서동 266-16번지  35.252358  129.093173   NaN
# 76  금정구              회동동 산129번지  35.244234  129.136831   NaN
#
# [77 rows x 5 columns]

# %% [markdown]
# # 전체 데이터

# %%
total = pd.concat([a,b])
total = total.reset_index(drop=True)
total
# Out:
#      관리구                                   위치          X           Y 위험등급
# 0    사상구  덕포동 775-1(덕상로 32), 덕상초등학교 주변 괘내교 인근  35.174645  128.990633    C
# 1    사상구                  엄궁동 141-15, ㈜이비알 근처  35.124170  128.965570    B
# 2    사상구                 엄궁동 138-2(엄궁로 70-10)  35.123331  128.974723    C
# 3    사상구              학장동 210-3번지, (동양아파트 일원)  35.143358  128.991617    C
# 4    사상구   주례동 616-4(주례로139번길 8), 주례벽산아파트 경사지  35.145078  129.001272    C
# ..   ...                                  ...        ...         ...  ...
# 213  금정구                          청룡동 176-1번지  35.277920  129.080970  NaN
# 214  금정구                          금성동 520-3번지  35.252502  129.057208  NaN
# 215  금정구                           선동 76-11번지  35.260309  129.118503  NaN
# 216  금정구                         구서동 266-16번지  35.252358  129.093173  NaN
# 217  금정구                           회동동 산129번지  35.244234  129.136831  NaN
#
# [218 rows x 5 columns]

# %%
total.to_excel('C:/Users/admin/Desktop/WithU-HJ/Bus_route/res/급경사지.xlsx')

# %% [markdown]
# ### 위험등급O 시각화

# %%
map3_danger = folium.Map((35.1795543,129.0756416), zoom_start=11)

for i in a.index:
  sub_lat = a.loc[i, 'X']
  sub_long = a.loc[i, 'Y']
  
  title = f"{a.loc[i, '관리구']} - {a.loc[i, '위험등급']}"
  
  if a.loc[i, '위험등급'] == 'B': 
    color='green',
  elif a.loc[i, '위험등급'] == 'C':
    color='yellow'
  elif a.loc[i, '위험등급'] == 'D':
    color='red'
  
  folium.CircleMarker(location=[sub_lat, sub_long],
                      radius=3,
                      color=color,
                      tooltip=title).add_to(map3_danger)

map3_danger
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ### 위험등급(X) 시각화

# %%
map = folium.Map((35.1795543,129.0756416), zoom_start=11)

for i in b.index:
  sub_lat = b.loc[i, 'X']
  sub_long = b.loc[i, 'Y']
  
  title = f"{b.loc[i, '관리구']}"
  
  color='blue'
  
  folium.CircleMarker(location=[sub_lat, sub_long],
                      radius=3,
                      color=color,
                      tooltip=title).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # Total

# %%
map= folium.Map((35.1795543,129.0756416), zoom_start=11)

for i in total.index:
  sub_lat = total.loc[i, 'X']
  sub_long = total.loc[i, 'Y']
  
  title = f"{total.loc[i, '관리구']} - {total.loc[i, '위험등급']}"
  
  
  if total.loc[i, '위험등급'] == 'B': 
    color='green',
  elif total.loc[i, '위험등급'] == 'C':
    color='yellow'
  elif total.loc[i, '위험등급'] == 'D':
    color='red'
  else:
    color='blue'
  
  folium.CircleMarker(location=[sub_lat, sub_long],
                      radius=3,
                      color=color,
                      tooltip=title).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
