# %%
import pandas as pd
import folium
import json

# %%
garage = pd.read_excel('C:/Users/admin/Desktop/WithU-HJ/data/부산 버스 차고지.xlsx')
garage
# Out:
#     정류소 번호           정류소 명                    주소         위도          경도
# 0  11275.0         금정공영차고지     부산광역시 금정구 노포동 223  35.289513  129.099096
# 1  11276.0    회동화물자동차공영차고지       부산광역시 금정구 금사회동동  35.243029  129.135872
# 2  13179.0       연제공용버스차고지  부산광역시 연제구 거제2동 월드컵대로  35.185471  129.053374
# 3  14118.0          민락동차고지         부산광역시 수영구 민락동  35.157826  129.125752
# 4  16262.0      청강리공영차고지입구         부산광역시 기장군 기장읍  35.223872  129.213255
# 5  16266.0        청강리공영차고지    부산광역시 기장군 기장대로 313  35.222438  129.212387
# 6      NaN         동남여객차고지   부산광역시 부산진구 개금2동 진사로  35.144284  129.016152
# 7      NaN           해동차고지        부산광역시 해운대구 송정동  35.194597  129.201637
# 8  11276.0  화동 화물자동차 공영차고지       부산광역시 금정구 금사회동동  35.243029  129.135872
# 9   4778.0         용당공영차고지          경상남도 양산시 서창동  35.427135  129.183383

# %%
bus = pd.read_excel('C:/Users/admin/Desktop/WithU-HJ/data/버스노선.xlsx')
bus
# Out:
#       BUSLINENUM  ORD       NAME SIGUNNAME GUNAME DONGNAME           X  \
# 0             10    1  연제공용버스차고지     부산광역시    연제구      NaN  129.053172
# 1             10    2       초읍고개     부산광역시    연제구      NaN  129.054089
# 2             10    3     개인택시조합     부산광역시    연제구     거제2동  129.055711
# 3             10    4      부산의료원     부산광역시    연제구     거제2동  129.060579
# 4             10    5    삼정그린아파트     부산광역시    연제구     거제2동  129.063026
# ...          ...  ...        ...       ...    ...      ...         ...
# 17287         99   63     동일고무벨트     부산광역시    금정구      금사동  129.114694
# 17288         99   64   부산예원고등학교     부산광역시    금정구      금사동  129.116679
# 17289         99   65    욱성화학(주)     부산광역시    금정구      금사동  129.118927
# 17290         99   66       회동본동     부산광역시    금정구      금사동  129.120305
# 17291         99   67        회동동     부산광역시    금정구      금사동  129.124222
#
#                Y UNIQUEID    BUSSTOPID
# 0      35.185243    13179  50000001059
# ...

# %%
busnumber = []
for i in bus.index:
    if bus.loc[i, 'GUNAME'] == '사상구':
        x = bus.loc[i , 'BUSLINENUM']
        if x in busnumber:
            continue 
        busnumber.append(x) 
print(busnumber)
# Out:
# ['1004', '1004(심야)', '1005', '108', '110', '123', '124', '126', '128-1', '129-1', '133', '138', '138-1', '148', '148-1', '15', '15(심야)', '16', '160', '161', '167', '168', '169', '169-1', '186', '31', '33', '33-1', '338', '59', '61', '62', '67', '68', '77', '8']

# %%
busnumber = pd.DataFrame(busnumber, columns = ['BUSLINENUM'])
busnumber
# Out:
#    BUSLINENUM
# 0        1004
# 1    1004(심야)
# 2        1005
# 3         108
# 4         110
# 5         123
# 6         124
# 7         126
# 8       128-1
# 9       129-1
# 10        133
# 11        138
# 12      138-1
# 13        148
# 14      148-1
# 15         15
# 16     15(심야)
# 17         16
# 18        160
# 19        161
# 20        167
# 21        168
# 22        169
# 23      169-1
# 24        186
# 25         31
# 26         33
# 27       33-1
# 28        338
# 29         59
# 30         61
# 31         62
# 32         67
# 33         68
# 34         77
# 35          8

# %%
bus_사상 = pd.merge(bus, busnumber, on = 'BUSLINENUM', how = 'inner')
bus_사상
# Out:
#      BUSLINENUM  ORD       NAME SIGUNNAME GUNAME DONGNAME           X  \
# 0          1004    1        구산동      경상남도    김해시      북부동  128.873779
# 1          1004    2    광남백조아파트      경상남도    김해시      북부동  128.875115
# 2          1004    3    청소년문화의집      경상남도    김해시      북부동  128.878207
# 3          1004    4       김해여고      경상남도    김해시      북부동  128.879692
# 4          1004    5    농협김해시지부      경상남도    김해시      회현동  128.881034
# ...         ...  ...        ...       ...    ...      ...         ...
# 4200          8   83    에덴금호아파트     부산광역시    영도구     동삼1동  129.076343
# 4201          8   84      해양대입구     부산광역시    영도구     동삼2동  129.078161
# 4202          8   85         하리     부산광역시    영도구     동삼2동  129.080833
# 4203          8   86    태종대초등학교     부산광역시    영도구     동삼2동  129.081032
# 4204          8   87  태종대.태종대온천     부산광역시    영도구     동삼2동  129.080944
#
#               Y UNIQUEID    BUSSTOPID
# 0     35.247717      NaN  38070551007
# 1     35.245740      NaN  38070551010
# ...

# %%
busnumber_1번노선 = []
for i in bus_사상.index:
    if bus_사상.loc[i, 'GUNAME'] == '북구':
        x = bus_사상.loc[i , 'BUSLINENUM']
        if x in busnumber_1번노선:
            continue 
        busnumber_1번노선.append(x) 
print(busnumber_1번노선)
# Out:
# ['1004', '1004(심야)', '110', '123', '124', '126', '128-1', '133', '148', '148-1', '15', '15(심야)', '160', '169', '169-1', '33', '33-1', '59']

# %%
busnumber_2번노선 = []
for i in bus_사상.index:
    if bus_사상.loc[i, 'GUNAME'] == '부산진구':
        x = bus_사상.loc[i , 'BUSLINENUM']
        if x in busnumber_2번노선:
            continue 
        busnumber_2번노선.append(x) 
print(busnumber_2번노선)
# Out:
# ['1004', '1004(심야)', '108', '124', '129-1', '133', '138', '138-1', '160', '167', '168', '169', '169-1', '186', '31', '33', '59', '61', '62', '67', '68', '77']

# %%
busnumber_3번노선 = []
for i in bus_사상.index:
    if bus_사상.loc[i, 'GUNAME'] == '사하구':
        x = bus_사상.loc[i , 'BUSLINENUM']
        if x in busnumber_3번노선:
            continue 
        busnumber_3번노선.append(x) 
print(busnumber_3번노선)
# Out:
# ['1005', '123', '126', '138', '138-1', '16', '161', '168', '338', '61', '68']

# %%
busnumber_4번노선 = []
for i in bus_사상.index:
    if bus_사상.loc[i, 'GUNAME'] == '해운대구':
        x = bus_사상.loc[i , 'BUSLINENUM']
        if x in busnumber_4번노선:
            continue 
        busnumber_4번노선.append(x) 
print(busnumber_4번노선)
# Out:
# ['129-1', '31']

# %% [markdown]
# # 버스번호

# %%
bus_33 = bus[bus['BUSLINENUM']== '33']
bus_133 = bus[bus['BUSLINENUM']== '133']
bus_123 = bus[bus['BUSLINENUM']== '123']
bus_126 = bus[bus['BUSLINENUM']== '126']
bus_169 = bus[bus['BUSLINENUM']== '169']
bus_15 = bus[bus['BUSLINENUM']== '15']
bus_160 = bus[bus['BUSLINENUM']== '160']
bus_169_1 = bus[bus['BUSLINENUM']== '169-1']
bus_59 = bus[bus['BUSLINENUM']== '59']
bus_33_1 = bus[bus['BUSLINENUM']== '33-1']
bus_110 = bus[bus['BUSLINENUM']== '110']
bus_124 = bus[bus['BUSLINENUM']== '124']
bus_128_1 = bus[bus['BUSLINENUM']== '128-1']
bus_148 = bus[bus['BUSLINENUM']== '148']
bus_148_1 = bus[bus['BUSLINENUM']== '148-1']
bus_31 = bus[bus['BUSLINENUM']== '31']
bus_68 = bus[bus['BUSLINENUM']== '68']
bus_168 = bus[bus['BUSLINENUM']== '168']
bus_108 = bus[bus['BUSLINENUM']== '108']
bus_67 = bus[bus['BUSLINENUM']== '67']
bus_138 = bus[bus['BUSLINENUM']== '138']
bus_138_1 = bus[bus['BUSLINENUM']== '138-1']
bus_61 = bus[bus['BUSLINENUM']== '61']
bus_186 = bus[bus['BUSLINENUM']== '186']
bus_62 = bus[bus['BUSLINENUM']== '62']
bus_129_1 = bus[bus['BUSLINENUM']== '129-1']
bus_77 = bus[bus['BUSLINENUM']== '77']
bus_16 = bus[bus['BUSLINENUM']== '16']
bus_161 = bus[bus['BUSLINENUM']== '161']
bus_338 = bus[bus['BUSLINENUM']== '338']
bus_1005 = bus[bus['BUSLINENUM']== '1005']
bus_1004 = bus[bus['BUSLINENUM']== '1004']
bus_33.head(3)
# Out:
#       BUSLINENUM  ORD       NAME SIGUNNAME GUNAME DONGNAME           X  \
# 10882         33    1  연제공용버스차고지     부산광역시    연제구      NaN  129.053172
# 10883         33    2      시민도서관     부산광역시   부산진구      초읍동  129.050616
# 10884         33    3     초읍초등학교     부산광역시   부산진구      초읍동  129.050645
#
#                Y UNIQUEID    BUSSTOPID
# 10882  35.185243    13179  50000001059
# 10883  35.183126     5061  21050551017
# 10884  35.180547     5041  21050551012

# %%
bus_stop = pd.concat([bus_33, bus_133, bus_123, bus_126 , bus_169 , bus_15, bus_160 , bus_169_1,bus_59 , bus_33_1, bus_110, bus_124, bus_128_1, 
                        bus_148, bus_148_1, bus_31, bus_68, bus_168, bus_108, bus_67, bus_138, bus_138_1, bus_61, bus_186, bus_62, bus_129_1, bus_77, bus_16, 
                        bus_161, bus_338, bus_1005, bus_1004], axis=0)
bus_stop
# Out:
#       BUSLINENUM  ORD       NAME SIGUNNAME GUNAME DONGNAME           X  \
# 10882         33    1  연제공용버스차고지     부산광역시    연제구      NaN  129.053172
# 10883         33    2      시민도서관     부산광역시   부산진구      초읍동  129.050616
# 10884         33    3     초읍초등학교     부산광역시   부산진구      초읍동  129.050645
# 10885         33    4      부산진고교     부산광역시   부산진구      초읍동  129.053737
# 10886         33    5     연지한신타워     부산광역시   부산진구      연지동  129.054522
# ...          ...  ...        ...       ...    ...      ...         ...
# 1424        1004  101    농협김해시지부      경상남도    김해시      회현동  128.881398
# 1425        1004  102       김해여고      경상남도    김해시      북부동  128.879513
# 1426        1004  103    청소년문화의집      경상남도    김해시      북부동  128.878440
# 1427        1004  104    광남백조아파트      경상남도    김해시      북부동  128.875277
# 1428        1004  105        구산동      경상남도    김해시      북부동  128.873972
#
#                Y UNIQUEID    BUSSTOPID
# 10882  35.185243    13179  50000001059
# ...

# %%
bus_stop.to_csv('C:/Users/admin/Desktop/WithU-HJ/Bus_route/res/bus_stop.csv')

# %%
lines_33 = bus_33[['Y', 'X']].values[:].tolist()
lines_133 = bus_133[['Y', 'X']].values[:].tolist()
lines_123 = bus_123[['Y', 'X']].values[:].tolist()
lines_126 = bus_126[['Y', 'X']].values[:].tolist()
lines_169 = bus_169[['Y', 'X']].values[:].tolist()
lines_15 = bus_15[['Y', 'X']].values[:].tolist()
lines_160 = bus_160[['Y', 'X']].values[:].tolist()
lines_169_1 = bus_169_1[['Y', 'X']].values[:].tolist()
lines_59 = bus_59[['Y', 'X']].values[:].tolist()
lines_33_1 = bus_33_1[['Y', 'X']].values[:].tolist()
lines_110 = bus_110[['Y', 'X']].values[:].tolist()
lines_124 = bus_124[['Y', 'X']].values[:].tolist()
lines_128_1 = bus_128_1[['Y', 'X']].values[:].tolist()
lines_148 = bus_148[['Y', 'X']].values[:].tolist()
lines_148_1 = bus_148_1[['Y', 'X']].values[:].tolist()
lines_31 = bus_31[['Y', 'X']].values[:].tolist()
lines_68 = bus_68[['Y', 'X']].values[:].tolist()
lines_168 = bus_168[['Y', 'X']].values[:].tolist()
lines_108 = bus_108[['Y', 'X']].values[:].tolist()
lines_67 = bus_67[['Y', 'X']].values[:].tolist()
lines_138 = bus_138[['Y', 'X']].values[:].tolist()
lines_138_1 = bus_138_1[['Y', 'X']].values[:].tolist()
lines_61 = bus_61[['Y', 'X']].values[:].tolist()
lines_186 = bus_186[['Y', 'X']].values[:].tolist()
lines_62 = bus_62[['Y', 'X']].values[:].tolist()
lines_129_1 = bus_129_1[['Y', 'X']].values[:].tolist()
lines_77 = bus_77[['Y', 'X']].values[:].tolist()
lines_16 = bus_16[['Y', 'X']].values[:].tolist()
lines_161 = bus_161[['Y', 'X']].values[:].tolist()
lines_338 = bus_338[['Y', 'X']].values[:].tolist()
lines_1005 = bus_1005[['Y', 'X']].values[:].tolist()
lines_1004 = bus_1004[['Y', 'X']].values[:].tolist()

# %% [markdown]
# # 1번 노선 (북구 <-> 사상구)

# %%
map = folium.Map((35.1795543,129.0756416), zoom_start=12)

folium.PolyLine(locations = lines_33).add_to(map)
folium.PolyLine(locations=lines_133, color='green').add_to(map)
folium.PolyLine(locations=lines_123, color='purple').add_to(map)
folium.PolyLine(locations=lines_126, color='orange').add_to(map)
folium.PolyLine(locations=lines_169, color='lightred').add_to(map)
folium.PolyLine(locations=lines_15, color='fuchsia').add_to(map)
folium.PolyLine(locations=lines_160, color='black').add_to(map)
folium.PolyLine(locations=lines_169_1, color='lime').add_to(map)
folium.PolyLine(locations=lines_59, color='teal').add_to(map)
folium.PolyLine(locations=lines_33_1, color='LemonChiffon').add_to(map)
folium.PolyLine(locations=lines_1004, color='deeppink').add_to(map)
folium.PolyLine(locations=lines_110, color='Maroon').add_to(map)
folium.PolyLine(locations=lines_124, color='indigo').add_to(map)
folium.PolyLine(locations=lines_128_1, color='firebrick').add_to(map)
folium.PolyLine(locations=lines_148, color='cyan').add_to(map)
folium.PolyLine(locations=lines_148_1, color='peru').add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # 2번 노선 (진구 <-> 사상구)

# %%
map = folium.Map((35.1795543,129.0756416), zoom_start=12)

folium.PolyLine(locations = lines_33).add_to(map)
folium.PolyLine(locations=lines_133, color='green').add_to(map)
folium.PolyLine(locations=lines_160, color='black').add_to(map)
folium.PolyLine(locations=lines_169, color='yellow').add_to(map)
folium.PolyLine(locations=lines_169_1, color='lime').add_to(map)
folium.PolyLine(locations=lines_68, color='red').add_to(map)
folium.PolyLine(locations=lines_168, color='peru').add_to(map)
folium.PolyLine(locations=lines_31, color='teal').add_to(map)
folium.PolyLine(locations=lines_108, color='fuchsia').add_to(map)
folium.PolyLine(locations=lines_61, color='cyan').add_to(map)
folium.PolyLine(locations=lines_186, color='firebrick').add_to(map)
folium.PolyLine(locations=lines_59, color='indigo').add_to(map)
folium.PolyLine(locations=lines_67, color='Maroon').add_to(map)
folium.PolyLine(locations=lines_138, color='deeppink').add_to(map)
folium.PolyLine(locations=lines_138_1, color='gray').add_to(map)
folium.PolyLine(locations=lines_62, color='LemonChiffon').add_to(map)
folium.PolyLine(locations=lines_1004, color='#3DFFB9').add_to(map)
folium.PolyLine(locations=lines_124, color='#780F5A').add_to(map)
folium.PolyLine(locations=lines_129_1, color='#8389C4').add_to(map)
folium.PolyLine(locations=lines_67, color='#9B8E06').add_to(map)
folium.PolyLine(locations=lines_77, color='#5E997E').add_to(map)
                
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # 3번 노선 (사하구 <-> 사상구)

# %%
map = folium.Map((35.1795543,129.0756416), zoom_start=12)

folium.PolyLine(locations=lines_123, color='purple').add_to(map)
folium.PolyLine(locations=lines_126, color='yellow').add_to(map)
folium.PolyLine(locations=lines_68, color='red').add_to(map)
folium.PolyLine(locations=lines_168, color='lime').add_to(map)
folium.PolyLine(locations=lines_61, color='blue').add_to(map)
folium.PolyLine(locations=lines_16, color='fuchsia').add_to(map)
folium.PolyLine(locations=lines_161, color='chocolate').add_to(map)
folium.PolyLine(locations=lines_338, color='indigo').add_to(map)
folium.PolyLine(locations=lines_138, color='deeppink').add_to(map)
folium.PolyLine(locations=lines_138_1, color='gray').add_to(map)
folium.PolyLine(locations=lines_1005, color='teal').add_to(map)
                
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # 4번 노선 (해운대구 <-> 사상구)

# %%
map = folium.Map((35.1795543,129.0756416), zoom_start=12)

folium.PolyLine(locations=lines_31).add_to(map)
folium.PolyLine(locations=lines_129_1, color='red').add_to(map)
                
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
